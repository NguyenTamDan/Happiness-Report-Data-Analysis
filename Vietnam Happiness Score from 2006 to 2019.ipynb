# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook, I am only trying to visualize and compare Ladder Score - also means as Happiness Score - and its score components on Vietnam in Asia and its surrounding neighbors. And I will not analyze the causes of the score in detail.

# %%
# Import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Styling the outputs
from matplotlib import style

font={'family':'sans-serif',
      'weight':'bold',
      'size':20}
plt.rc('font',**font)
style.use('fivethirtyeight')

# %%
# Import the dataset
world_2021 = pd.read_csv('world-happiness-report-2021.csv')
world_happiness = pd.read_csv('world-happiness-report.csv')

# %%
world_happiness
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ## Vietnam from 2006 to 2021

# %%
Vietnam = world_happiness[world_happiness['Country name'] == 'Vietnam']

# %%
Vietnam
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1894      Vietnam  2006        5.294               8.335           0.888
# 1895      Vietnam  2007        5.422               8.394           0.856
# 1896      Vietnam  2008        5.480               8.440           0.805
# 1897      Vietnam  2009        5.304               8.483           0.815
# 1898      Vietnam  2010        5.296               8.535           0.787
# 1899      Vietnam  2011        5.767               8.585           0.898
# 1900      Vietnam  2012        5.535               8.626           0.775
# 1901      Vietnam  2013        5.023               8.668           0.759
# 1902      Vietnam  2014        5.085               8.716           0.792
# 1903      Vietnam  2015        5.076               8.770           0.849
# 1904      Vietnam  2016        5.062               8.820           0.876
# 1905      Vietnam  2017        5.175               8.876             NaN
# ...

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Life Ladder', marker = 'o')
plt.title('Life Ladder')
plt.show()

# %% [markdown]
# There are certain peaks with regards to Vietnam's ladder score as seen in the years 2008, 2011, 2012 and 2019. There are also certain drops as seen in the years 2009, 2010, and an overall low in 2013. A increase can be seen from 2013 to 2019. The overall trend of the ladder score in this period fluctuates continuously over the years.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Log GDP per capita', marker = 'o')
plt.title('Log GDP per capita')
plt.show()

# %% [markdown]
# Vietnam's GDP is on an increasing trend over the years.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Social support', marker = 'o')
plt.title('Social Support')
plt.show()

# %% [markdown]
# There are some distinct lows in 2010, 2013 and 2018. 2013 had the lowest index and some distinct highs in 2006, 2011 and 2016.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Healthy life expectancy at birth', marker = 'o')
plt.title('Healthy life expectancy at birth')
plt.show()

# %% [markdown]
# Vietnam's Healthy life expectancy at birth is on an increasing trend over the years.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Freedom to make life choices', marker = 'o')
plt.title('Freedom to make life choices')
plt.show()

# %% [markdown]
# There's a slight increasing trend, but there are distincts drops as seen in years 2009 and 2011. The lowest index in this period is in year 2011.There are certain peaks with regards to India's Freedom to make life choices as seen in the years 2007, 2013 and 2019.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Generosity', marker = 'o')
plt.title('Generosity')
plt.show()

# %% [markdown]
# Generosity amongst Vietnamese people have increased over time.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Perceptions of corruption', marker = 'o')
plt.title('Perceptions of Corruption')
plt.show()

# %% [markdown]
# The years 2007, 2010 and 2011 had distinct drops in this period. There is a decreasing trend over the years.

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = Vietnam, x = 'year', y = 'Positive affect', marker = 'o')
plt.title('Positive affect')
plt.show()

# %% [markdown]
# This variable fluctuated countinuosly over the years. The highest index is in the year 2019.

# %% [markdown]
# ## Vietnam in Asia

# %%
world_2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
world_2021[world_2021['Country name'] == 'Vietnam']
# Out:
#    Country name Regional indicator  Ladder score  \
# 78      Vietnam     Southeast Asia         5.411
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 78                           0.039         5.488         5.334
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 78                  8.973            0.85                   68.034
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 78                          0.94      -0.098                      0.796
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 78                      2.43                             0.817
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 78                         0.873                                  0.616
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 78                                       0.679                     0.124
#
# ...

# %%
southeast_asia = world_2021[world_2021['Regional indicator'] == 'Southeast Asia']
south_asia = world_2021[world_2021['Regional indicator'] == 'South Asia']
east_asia = world_2021[world_2021['Regional indicator'] == 'East Asia']

# %%
# Add east_asia to south_asia
south_east_asia = south_asia.append(east_asia)

# %%
# Create asia table
asia = south_east_asia.append(southeast_asia).sort_values(by = 'Ladder score', ascending = False).reset_index()

# %%
asia
# Out:
#     index               Country name Regional indicator  Ladder score  \
# 0      23   Taiwan Province of China          East Asia         6.584
# 1      31                  Singapore     Southeast Asia         6.377
# 2      53                   Thailand     Southeast Asia         5.985
# 3      55                      Japan          East Asia         5.940
# 4      60                Philippines     Southeast Asia         5.880
# 5      61                South Korea          East Asia         5.845
# 6      69                   Mongolia          East Asia         5.677
# 7      76  Hong Kong S.A.R. of China          East Asia         5.477
# 8      78                    Vietnam     Southeast Asia         5.411
# 9      80                   Malaysia     Southeast Asia         5.384
# 10     81                  Indonesia     Southeast Asia         5.345
# 11     83                      China          East Asia         5.339
# ...

# %% [markdown]
# * Vietnam is the 9th most happiness country in Asia.
# * In the world context, Vietnam ranks 78th.

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Ladder score', data = east_asia, marker = 'o', label = 'East Asia')
sns.lineplot(x = 'Country name', y = 'Ladder score', data = southeast_asia, marker = 'o', label = 'Southeast Asia')
sns.lineplot(x = 'Country name', y = 'Ladder score', data = south_asia, marker = 'o', label = 'South Asia')


plt.show()

# %% [markdown]
# ## Vietnam and its neighbors in 2021

# %%
southeast_asia
# Out:
#     Country name Regional indicator  Ladder score  \
# 31     Singapore     Southeast Asia         6.377
# 53      Thailand     Southeast Asia         5.985
# 60   Philippines     Southeast Asia         5.880
# 78       Vietnam     Southeast Asia         5.411
# 80      Malaysia     Southeast Asia         5.384
# 81     Indonesia     Southeast Asia         5.345
# 99          Laos     Southeast Asia         5.030
# 113     Cambodia     Southeast Asia         4.830
# 125      Myanmar     Southeast Asia         4.426
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 31                            0.043         6.460         6.293
# 53                            0.047         6.077         5.893
# 60                            0.052         5.982         5.778
# 78                            0.039         5.488         5.334
# 80                            0.049         5.480         5.289
# 81                            0.056         5.454         5.235
# ...

# %% [markdown]
# ### Ladder score

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Ladder score', data = southeast_asia, 
             marker = 'o')
plt.title('Ladder scores of Vietnam and its neighbors')
plt.show()

# %% [markdown]
# Among neighbors countries, Vietnam ranks 4th in the ladder score.

# %% [markdown]
# ### Logged GDP per capita

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Logged GDP per capita', 
             data = southeast_asia.sort_values(by = 'Logged GDP per capita', ascending = False), 
             marker = 'o')

plt.show()

# %% [markdown]
# Vietnam ranks 4th last in GDP.

# %% [markdown]
# ### Social Support

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Social support', 
             data = southeast_asia.sort_values(by = 'Social support', ascending = False), 
             marker = 'o')

plt.show()

# %% [markdown]
# Vietnam is in top 3 countries have highest index of social support.

# %% [markdown]
# ### Healthy Life Expectancy

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Healthy life expectancy', 
             data = southeast_asia.sort_values(by = 'Healthy life expectancy', ascending = False), 
             marker = 'o')

plt.show()

# %% [markdown]
# Vietnam ranks 2nd in Healthy life expectancy.

# %% [markdown]
# ### Freedom to Make Life Choices

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Freedom to make life choices', 
             data = southeast_asia.sort_values(by = 'Freedom to make life choices', ascending = False), 
             marker = 'o')

plt.show()

# %% [markdown]
# Vietnam ranks 2nd in Freedom to make life choices.

# %% [markdown]
# ### Generosity

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Generosity', 
             data = southeast_asia.sort_values(by = 'Generosity', ascending = False), 
             marker = 'o')

plt.show()

# %% [markdown]
# ### Perceptions of Corruption

# %%
plt.figure(figsize = (13, 6))
plt.xticks(rotation = 45, ha = 'right')

sns.lineplot(x = 'Country name', y = 'Perceptions of corruption', 
             data = southeast_asia.sort_values(by = 'Perceptions of corruption', ascending = False), 
             marker = 'o')

plt.show()
